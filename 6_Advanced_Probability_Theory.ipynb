# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
titanic = pd.read_csv('data/titanic.csv')
titanic.tail()
# Out:
#                           name gender   age             class embarked  \
# 2202          Wynn, Mr. Walter   male  41.0         deck crew        B
# 2203       Yearsley, Mr. Harry   male  40.0  victualling crew        S
# 2204  Young, Mr. Francis James   male  32.0  engineering crew        S
# 2205       Zanetti, Sig. Minio   male  20.0  restaurant staff        S
# 2206        Zarracchi, Sig. L.   male  26.0  restaurant staff        S
#
#       country  ticketno  fare  survived
# 2202  England       NaN   NaN         1
# 2203  England       NaN   NaN         1
# 2204  England       NaN   NaN         0
# 2205  England       NaN   NaN         0
# 2206  England       NaN   NaN         0

# %%
titanic['survived'] = np.where(titanic['survived']==1, 'yes', 'no')
titanic = titanic[['gender', 'survived']]
titanic.tail()
# Out:
#      gender survived
# 2202   male      yes
# 2203   male      yes
# 2204   male       no
# 2205   male       no
# 2206   male       no

# %%
num_rows = float(titanic.shape[0])
print(num_rows)
p_male = (titanic.gender=="male").sum() / num_rows     # == .65
print(p_male)
p_female = 1 - p_male # == .35
print(p_female)
# Out:
# 2207.0
# 0.7784322609877662
# 0.2215677390122338

# %%
p_survived = (titanic.survived=="yes").sum() / num_rows # == .38
print(p_survived)
p_notsurvived = 1 - p_survived                 # == .61
print(p_notsurvived)
# Out:
# 0.3221567739012234
# 0.6778432260987766

# %%
number_of_women = titanic[titanic.gender=='female'].shape[0]
women_who_lived = titanic[(titanic.gender=='female') & (titanic.survived=='yes')].shape[0]
p_survived_given_woman = women_who_lived / float(number_of_women)
p_survived_given_woman
# Out:
# 0.7341513292433538

# %%
import random
def random_variable_of_dice_roll():
    return random.randint(1, 6)

# %%
num_trials = range(100,10000, 10)
avgs = []
for num_trial in num_trials:
    trials = []
    for trial in range(1,num_trial):
        trials.append( random_variable_of_dice_roll() )
    avgs.append(sum(trials)/float(num_trial))

plt.plot(num_trials, avgs)
plt.xlabel('Number of Trials')
plt.ylabel("Average")
# Out:
# Text(0, 0.5, 'Average')

# %%
def normal_pdf(x, mu = 0, sigma = 1):
    return (1./np.sqrt(2*3.14 * sigma**2)) * 2.718**(-(x-mu)**2 / (2. * sigma**2))

# %%
x_values = np.linspace(-10,10,100)
y_values = [normal_pdf(x) for x in x_values]
plt.plot(x_values, y_values)

# %%
x_values = np.linspace(-10,10,100)
y_values = [normal_pdf(x, sigma = 5) for x in x_values]
plt.plot(x_values, y_values)

# %%
x_values = np.linspace(-20,20,100)
y_values = [normal_pdf(x, mu = -5, sigma = 5) for x in x_values]
plt.plot(x_values, y_values)
